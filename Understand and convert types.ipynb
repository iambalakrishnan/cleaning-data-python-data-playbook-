# %%
import pandas as pd

# %%
data = pd.read_csv('artwork_sample.csv')
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear         int64
# dimensions             object
# width                   int64
# height                  int64
# depth                 float64
# units                  object
# inscription           float64
# thumbnailCopyright    float64
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
data.acquisitionYear.dtypes
# Out:
# dtype('int64')

# %%
data.acquisitionYear.astype('float')
# Out:
# 0    1922.0
# 1    1922.0
# 2    1922.0
# 3    1922.0
# 4    1919.0
# 5    1919.0
# 6    1919.0
# 7    1919.0
# 8    1919.0
# 9    1919.0
# Name: acquisitionYear, dtype: float64

# %%
data.acquisitionYear = data.acquisitionYear.astype('float')

# %%
data.acquisitionYear.dtypes
# Out:
# dtype('float64')

# %%
fulldf = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
fulldf.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
fulldf.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
fulldf.shape
# Out:
# (69201, 20)

# %%
fulldf.describe()
# Out:
#                   id      artistId  acquisitionYear         depth
# count   69201.000000  69201.000000     69156.000000   2514.000000
# mean    39148.026213   1201.063251      1910.646856    479.197772
# std     25980.468687   2019.422535        64.202148   1051.141734
# min         3.000000      0.000000      1823.000000      1.000000
# 25%     19096.000000    558.000000      1856.000000     48.250000
# 50%     37339.000000    558.000000      1856.000000    190.000000
# 75%     54712.000000   1137.000000      1982.000000    450.000000
# max    129068.000000  19232.000000      2013.000000  18290.000000

# %%
fulldf.height.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-99c9ee63bec2> in <module>
# ----> 1 fulldf.height.astype(float)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
pd.to_numeric(fulldf.height)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mm"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2a281090024b> in <module>
# ----> 1 pd.to_numeric(fulldf.height)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mm" at position 41339

# %%
pd.to_numeric(fulldf.height, errors = "coerce")
# Out:
# 0         419.0
# 1         213.0
# 2         467.0
# 3         394.0
# 4         335.0
#           ...
# 69196     305.0
# 69197     305.0
# 69198    2410.0
# 69199       NaN
# 69200     660.0
# Name: height, Length: 69201, dtype: float64

# %%
pd.to_numeric(fulldf.height, errors = 'coerce')[41339]
# Out:
# nan

# %%
data.height = pd.to_numeric(fulldf.height, errors = 'coerce')

# %%
data.height.dtypes
# Out:
# dtype('float64')

# %%
data.year
# Out:
# 0       NaN
# 1       NaN
# 2    1785.0
# 3       NaN
# 4    1826.0
# 5    1826.0
# 6    1826.0
# 7    1826.0
# 8    1826.0
# 9    1826.0
# Name: year, dtype: float64

# %%
data.artist.min()
# Out:
# 'Blake, Robert'

# %%
data.artist.max()
# Out:
# 'Blake, William'

# %%
data.min()
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistRole                                                       artist
# artistId                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText                                         1826–7, reprinted 1892
# medium                                                Graphite on paper
# creditLine                          Presented by Mrs John Richmond 1922
# year                                                             1785.0
# acquisitionYear                                                  1919.0
# dimensions                                          image: 240 x 338 mm
# width                                                               240
# ...

# %%
data.agg(min)
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistRole                                                       artist
# artistId                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText                                         1826–7, reprinted 1892
# medium                                                Graphite on paper
# creditLine                          Presented by Mrs John Richmond 1922
# year                                                             1785.0
# acquisitionYear                                                  1919.0
# dimensions                                          image: 240 x 338 mm
# width                                                               240
# ...

# %%
data.agg('max')
# Out:
# id                                                                 1044
# accession_number                                                 A00010
# artist                                                   Blake, William
# artistRole                                                       artist
# artistId                                                             39
# title                 Two Drawings of Frightened Figures, Probably f...
# dateText                                                 date not known
# medium                Watercolour, ink, chalk and graphite on paper....
# creditLine            Purchased with the assistance of a special gra...
# year                                                             1826.0
# acquisitionYear                                                  1922.0
# dimensions                                        support: 394 x 419 mm
# width                                                               394
# ...

# %%
data.agg('sum')
# Out:
# id                                                                10395
# accession_number      A00001A00002A00003A00004A00005A00006A00007A000...
# artist                Blake, RobertBlake, RobertBlake, RobertBlake, ...
# artistRole            artistartistartistartistartistartistartistarti...
# artistId                                                            386
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText              date not knowndate not known?c.1785date not kn...
# medium                Watercolour, ink, chalk and graphite on paper....
# creditLine            Presented by Mrs John Richmond 1922Presented b...
# year                                                            12741.0
# acquisitionYear                                                 19202.0
# dimensions            support: 394 x 419 mmsupport: 311 x 213 mmsupp...
# width                                                              2821
# ...

# %%
data.agg(['min','max','mean','var','std'])
# Out:
#                id accession_number          artist artistRole   artistId  \
# min   1035.000000           A00001   Blake, Robert     artist  38.000000
# max   1044.000000           A00010  Blake, William     artist  39.000000
# mean  1039.500000              NaN             NaN        NaN  38.600000
# var      9.166667              NaN             NaN        NaN   0.266667
# std      3.027650              NaN             NaN        NaN   0.516398
#
#                                                   title  \
# min   A Figure Bowing before a Seated Old Man with h...
# max   Two Drawings of Frightened Figures, Probably f...
# mean                                                NaN
# var                                                 NaN
# std                                                 NaN
#
#                     dateText  \
# min   1826–7, reprinted 1892
# max           date not known
# mean                     NaN
# var                      NaN
# std                      NaN
#
# ...

# %%
data.describe()
# Out:
#                id   artistId         year  acquisitionYear       width  \
# count    10.00000  10.000000     7.000000        10.000000   10.000000
# mean   1039.50000  38.600000  1820.142857      1920.200000  282.100000
# std       3.02765   0.516398    15.496543         1.549193   55.562677
# min    1035.00000  38.000000  1785.000000      1919.000000  240.000000
# 25%    1037.25000  38.000000  1826.000000      1919.000000  242.250000
# 50%    1039.50000  39.000000  1826.000000      1919.000000  244.500000
# 75%    1041.75000  39.000000  1826.000000      1922.000000  316.250000
# max    1044.00000  39.000000  1826.000000      1922.000000  394.000000
#
#            height  depth  inscription  thumbnailCopyright
# count   10.000000    0.0          0.0                 0.0
# mean   351.500000    NaN          NaN                 NaN
# std     66.818577    NaN          NaN                 NaN
# min    213.000000    NaN          NaN                 NaN
# ...

# %%
data.agg('mean', axis=1)
# Out:
# Series([], dtype: float64)

# %%
data.height.min()
# Out:
# 213.0

# %%
data.height.min()
# Out:
# 213.0

# %%
data.height.sum()
# Out:
# 3515.0

# %%
data.height.std()
# Out:
# 66.81857692455162

# %%
data.height.median()
# Out:
# 339.0

# %%
data.height.var()
# Out:
# 4464.722222222223

# %%
height = data.height

# %%
height
# Out:
# 0    419.0
# 1    213.0
# 2    467.0
# 3    394.0
# 4    335.0
# 5    338.0
# 6    334.0
# 7    340.0
# 8    335.0
# 9    340.0
# Name: height, dtype: float64

# %%
#Standardization of data

norm = (height - height.mean()) / height.std()

# %%
norm
# Out:
# 0    1.010198
# 1   -2.072777
# 2    1.728561
# 3    0.636051
# 4   -0.246937
# 5   -0.202040
# 6   -0.261903
# 7   -0.172108
# 8   -0.246937
# 9   -0.172108
# Name: height, dtype: float64

# %%
#Normalize all the value between zero and one
minmax = (height - height.min()) / (height.max() - height.min())
minmax
# Out:
# 0    0.811024
# 1    0.000000
# 2    1.000000
# 3    0.712598
# 4    0.480315
# 5    0.492126
# 6    0.476378
# 7    0.500000
# 8    0.480315
# 9    0.500000
# Name: height, dtype: float64

# %%
minmax.min()
# Out:
# 0.0

# %%
minmax.max()
# Out:
# 1.0

# %%
minmax.std()
# Out:
# 0.26306526348248666

# %%
minmax.median()
# Out:
# 0.49606299212598426

# %%
data['standardized_height'] = norm

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.new_column = norm
# Out:
# <ipython-input-79-5c667d23da12>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.new_column = norm

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
#Transforming data
data.height.transform(lambda x: print(x))
# Out:
# 419.0
# 213.0
# 467.0
# 394.0
# 335.0
# 338.0
# 334.0
# 340.0
# 335.0
# 340.0
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: height, dtype: object

# %%
data.height.transform(lambda x: x)
# Out:
# 0    419.0
# 1    213.0
# 2    467.0
# 3    394.0
# 4    335.0
# 5    338.0
# 6    334.0
# 7    340.0
# 8    335.0
# 9    340.0
# Name: height, dtype: float64

# %%
#lets convert height by diving 10

data.height.transform(lambda x: x/10)
# Out:
# 0    41.9
# 1    21.3
# 2    46.7
# 3    39.4
# 4    33.5
# 5    33.8
# 6    33.4
# 7    34.0
# 8    33.5
# 9    34.0
# Name: height, dtype: float64

# %%
data.groupby('artist')

# %%
data.groupby('artist').transform('nunique')
# Out:
#    id  accession_number  artistRole  artistId  title  dateText  medium  \
# 0   4                 4           1         1      4         2       3
# 1   4                 4           1         1      4         2       3
# 2   4                 4           1         1      4         2       3
# 3   4                 4           1         1      4         2       3
# 4   6                 6           1         1      6         1       1
# 5   6                 6           1         1      6         1       1
# 6   6                 6           1         1      6         1       1
# 7   6                 6           1         1      6         1       1
# 8   6                 6           1         1      6         1       1
# 9   6                 6           1         1      6         1       1
#
#    creditLine  year  acquisitionYear  dimensions  width  height  depth  units  \
# 0           1     1                1           4      4       4      0      1
# ...

# %%
data.groupby('artist')['height'].transform('mean')
# Out:
# 0    373.25
# 1    373.25
# 2    373.25
# 3    373.25
# 4    337.00
# 5    337.00
# 6    337.00
# 7    337.00
# 8    337.00
# 9    337.00
# Name: height, dtype: float64

# %%
data.artist
# Out:
# 0     Blake, Robert
# 1     Blake, Robert
# 2     Blake, Robert
# 3     Blake, Robert
# 4    Blake, William
# 5    Blake, William
# 6    Blake, William
# 7    Blake, William
# 8    Blake, William
# 9    Blake, William
# Name: artist, dtype: object

# %%
data['mean_height_by_atrist'] = data.groupby('artist')['height'].transform('mean')

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data = pd.read_csv('artwork_data.csv', low_memory = False )

# %%
data.shape
# Out:
# (69201, 20)

# %%
#Filetering columns which we want to look into 
#items parms takes list of columns names which we want 
data.filter(items=['id','artist'])
# Out:
#            id              artist
# 0        1035       Blake, Robert
# 1        1036       Blake, Robert
# 2        1037       Blake, Robert
# 3        1038       Blake, Robert
# 4        1039      Blake, William
# ...       ...                 ...
# 69196  122960  P-Orridge, Genesis
# 69197  122961  P-Orridge, Genesis
# 69198  121181        Hatoum, Mona
# 69199  112306       Creed, Martin
# 69200  127035   Brunias, Agostino
#
# [69201 rows x 2 columns]

# %%
#Like parm will find column likewise
data.filter(like='year')
# Out:
#        year
# 0       NaN
# 1       NaN
# 2      1785
# 3       NaN
# 4      1826
# ...     ...
# 69196  1975
# 69197  1976
# 69198  1996
# 69199  2000
# 69200  1764
#
# [69201 rows x 1 columns]

# %%
#like param case sensitive by default
data.filter(like='Year')
# Out:
#        acquisitionYear
# 0               1922.0
# 1               1922.0
# 2               1922.0
# 3               1922.0
# 4               1919.0
# ...                ...
# 69196           2013.0
# 69197           2013.0
# 69198           2013.0
# 69199           2013.0
# 69200           2013.0
#
# [69201 rows x 1 columns]

# %%
data.filter(like='artist')
# Out:
#                    artist artistRole  artistId
# 0           Blake, Robert     artist        38
# 1           Blake, Robert     artist        38
# 2           Blake, Robert     artist        38
# 3           Blake, Robert     artist        38
# 4          Blake, William     artist        39
# ...                   ...        ...       ...
# 69196  P-Orridge, Genesis     artist     16646
# 69197  P-Orridge, Genesis     artist     16646
# 69198        Hatoum, Mona     artist      2365
# 69199       Creed, Martin     artist      2760
# 69200   Brunias, Agostino     artist      3824
#
# [69201 rows x 3 columns]

# %%
#If we require full control ignoring case sensitive use regex 
data.filter(regex="(?i)year")
# Out:
#        year  acquisitionYear
# 0       NaN           1922.0
# 1       NaN           1922.0
# 2      1785           1922.0
# 3       NaN           1922.0
# 4      1826           1919.0
# ...     ...              ...
# 69196  1975           2013.0
# 69197  1976           2013.0
# 69198  1996           2013.0
# 69199  2000           2013.0
# 69200  1764           2013.0
#
# [69201 rows x 2 columns]

# %%
 data.filter(axis=0, regex="^100.$")
# Out:
#          id accession_number                          artist artistRole  \
# 1000  14704           A01004  Turner, Joseph Mallord William     artist
# 1001  14705           A01005  Turner, Joseph Mallord William     artist
# 1002  14706           A01006  Turner, Joseph Mallord William     artist
# 1003  14707           A01007  Turner, Joseph Mallord William     artist
# 1004  14708           A01008  Turner, Joseph Mallord William     artist
# 1005  14709           A01009  Turner, Joseph Mallord William     artist
# 1006  14710           A01010  Turner, Joseph Mallord William     artist
# 1007  14711           A01011  Turner, Joseph Mallord William     artist
# 1008  14712           A01012  Turner, Joseph Mallord William     artist
# 1009  14713           A01013  Turner, Joseph Mallord William     artist
#
#       artistId                                              title dateText  \
# 1000       558                               Hedging and Ditching     1812
# ...

# %%
data.filter(regex="^100(0|2|4|6|8)$", axis=0)
# Out:
#          id accession_number                          artist artistRole  \
# 1000  14704           A01004  Turner, Joseph Mallord William     artist
# 1002  14706           A01006  Turner, Joseph Mallord William     artist
# 1004  14708           A01008  Turner, Joseph Mallord William     artist
# 1006  14710           A01010  Turner, Joseph Mallord William     artist
# 1008  14712           A01012  Turner, Joseph Mallord William     artist
#
#       artistId                                    title dateText  \
# 1000       558                     Hedging and Ditching     1812
# 1002       558                                River Wye     1812
# 1004       558  Chain of Alps from Grenoble to Chamberi     1812
# 1006       558                             Mer de Glace     1812
# 1008       558                  Rivaux Abbey, Yorkshire     1812
#
#                               medium  \
# 1000  Etching and engraving on paper
# 1002                  Print on paper
# ...
